# %%
#count number of characters in a string
string=input("Enter a text:")
print(len(string))
# Out:
# Enter a text: dkfj
# 4

# %%
#reverse the string
string=input("Enter a text:")
print(string[::-1])
# Out:
# Enter a text: Harsh
# hsraH

# %%
#check if a string is palindrome
string=input("Enter a text:")
if string==string[::-1]:
    print("This text is a palindrome")
else:
    print("This text is not a palindrome")
# Out:
# Enter a text: refer
# This text is a palindrome

# %%
#count vowels and consonants in a string
text=input("Enter a text:")
vowel=0
consonant=0
for ch in text:
    if ch in "aeiou" and ch.isalpha():
        vowel+=1
    else:
        consonant+=1
print(vowel)
print(consonant)
# Out:
# Enter a text: Harsitha Dhasnamurthi
# 7
# 14

# %%
#convert string into upper and lower case
string=input("Enter a text:")
print("Upper case of the text:", string.upper())
print("Lower case of the text:", string.lower())
# Out:
# Enter a text: Harsh
# Upper case of the text: HARSH
# Lower case of the text: harsh

# %%
#remove space from a string
text=input("Enter a text:")
result=""
for i in text:
    if i!=" ":
        result+=i
print(result)
# Out:
# Enter a text: Har Nan Rus
# HarNanRus

# %%
#replace word in a sentence
text= "Today is the first day of my internship"
result=text.replace("of my internship","as an intern")
print(result)
# Out:
# Today is the first day as an intern

# %%
#count frequency of each character
text= input("Enter a text:").lower()
for ch in set(text):
    c=text.count(ch)
    print(f"{ch} : {c}")
# Out:
# Enter a text: Nandhini
# a : 1
# d : 1
# n : 3
# h : 1
# i : 2

# %%
#extract substring from a string
text=input("Enter a string:")
print(text[0:6])

# %%
#check if two string are anagrams
string1=input("String1")
string2=input("string2")
sort_s1= sorted(string1)
sort_s2=sorted(string2)
print(sort_s1)
print(sort_s2)
if sort_s1==sort_s2:
    print("The strings are anagram")
else:
    print("It's not an anagram")
# Out:
# String1 har
# string2 arh
# ['a', 'h', 'r']
# ['a', 'h', 'r']
# The strings are anagram

# %%
#create a list and print first and last element
l=['h','a','r','s','h']
print("First element is:", l[0])
print("Second element is:", l[-1])
# Out:
# First element is: h
# Second element is: h

# %%
#add and remove elements from a list
l=['h','a','r','s','h']
l.append("u")
print(l)
l.remove("u")
print(l)
# Out:
# ['h', 'a', 'r', 's', 'h', 'u']
# ['h', 'a', 'r', 's', 'h']

# %%
#find maximum and minimum in a list
l=['h','a','r','s','h']
print(max(l))
print(min(l))
# Out:
# s
# a

# %%
#reverse a list
l=['h','a','r','s','h']
print(l[::-1])
# Out:
# ['h', 's', 'r', 'a', 'h']

# %%
#sort a list in ascending and descending order
l=[33,45,11,65,87,56,37,78,98,77]
l.sort()
print("Ascending:",l)
l.sort(reverse=True)
print("Desending:",l)
# Out:
# Ascending: [11, 33, 37, 45, 56, 65, 77, 78, 87, 98]
# Desending: [98, 87, 78, 77, 65, 56, 45, 37, 33, 11]

# %%
#count occurrences of an element
l=['h','a','r','s','i','e','h','e']
for ch in l:
    c=l.count(ch)
    print(f"{ch} : {c}") 

#for a specific element
ch=input("Enter an element")
if ch in l:
    print(l.count(ch))
# Out:
# h : 2
# a : 1
# r : 1
# s : 1
# i : 1
# e : 2
# h : 2
# e : 2
# Enter an element a
# 1

# %%
#merge two lists
l1=['h','a','r']
l2=['s','i','t','h','a']
print(l1+l2)
# Out:
# ['h', 'a', 'r', 's', 'i', 't', 'h', 'a']

# %%
#remove duplicates from a list
l=['h', 'a', 'r', 's', 'i', 't', 'h', 'a']

print(list(set(l)))

#technique 2

unique=[]
for i in l:
    if i not in unique:
        unique.append(i)
print(unique)
# Out:
# ['t', 'a', 'r', 's', 'h', 'i']
# ['h', 'a', 'r', 's', 'i', 't']

# %%
#find second largest element in a list
l=[33,45,11,65,87,56,37,78,98,77]
l.sort()
print("Ascending:",l)
print ("The 2nd largest element in a list is:",l[-2])

# %%
#split list into even and odd numbers
l=[33,45,11,65,87,56,37,78,98,77]
even=[]
odd=[]
for num in l:
    if num%2==0:
        even.append(num)
    else:
        odd.append(num)
print("The even list is:",even)
print("The odd list is:",odd)
# Out:
# The even list is: [56, 78, 98]
# The odd list is: [33, 45, 11, 65, 87, 37, 77]

# %%
#createa tuple and print element
tup =(3,4,5,5,9)
print(tup[0])
# Out:
# 3

# %%
#convert tuple to list and modify it 
tup =(3,4,5,5,9)
l=list(tup)
l.append(10)
print(l)
# Out:
# [3, 4, 5, 5, 9, 10]

# %%
#count occurences of an element in tuple 
tup =('h','a','r','s','a','s','i')
count=0
for i in tup:
    c=tup.count(i)
    print(f"{i}:{c}")
# Out:
# h:1
# a:2
# r:1
# s:2
# a:2
# s:2
# i:1

# %%
#find index of an element in tuple
tup=(3,4,5,6,7)
print(tup.index(5))
# Out:
# 2

# %%
t1=(1,2,3)
t2=(4,5,6)
print(t1+t2)

# %%
#check if an element exists in tuple
tup =('h','a','r','s','a','s','i')
print(tup[2:5])
# Out:
# ('r', 's', 'a')

# %%
#check if an element exists in tuple
tup =('h','a','r','s','a','s','i')
element=input("Enter an element:").lower()
if element in tup:
    print("Yes")
else:
    print("No")
# Out:
# Enter an element: H
# Yes

# %%
#find length of a tuple
tup =('h','a','r','s','a','s','i')
print(len(tup))
# Out:
# 7

# %%
#convert list to tuple
lis=['h','a','r','s','a','s','i']
print(tuple(lis))
# Out:
# ('h', 'a', 'r', 's', 'a', 's', 'i')

# %%
#iterate through tuple elements
tup=('h','a','r','s','a','s','i')
for i in tup:
    print(i)
# Out:
# h
# a
# r
# s
# a
# s
# i

# %%
#create a set and print unique elements
s={'a','e'}
print(s)
# Out:
# {'e', 'a'}

# %%
#add elements to a set
s={'a','e'}
s.add('i')
print(s)
# Out:
# {'e', 'a', 'i'}

# %%
#remove elements from a set
s={'a','e'}
s.remove('a')
print(s)
# Out:
# {'e'}

# %%
#perform union of two sets
s1={1,2,3}
s2={3,4,5}
s=s1.union(s2)
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
#perform intersection of two sets
s1={1,2,3}
s2={3,4,5}
s=s1.intersection(s2)
print(s)
# Out:
# {3}

# %%
#find difference between two sets
s1={1,2,3}
s2={3,4,5}
s=s1-s2
print(s)
# Out:
# {1, 2}

# %%
#check if element exists in a set
s={'a','e','i','o','u'}
element=input("Enter an element:").lower()
if element in s:
    print("Exists")
else:
    print("Doesn't exists")
# Out:
# Enter an element: H
# Doesn't exists

# %%
#remove duplicates from a list using set
s={'h','a','r','s','a','s','i'}
d=list(s)
empt=[]
for i in s:
    if i not in empt:
        empt.append(i)
print(empt)
# Out:
# ['a', 'r', 's', 'h', 'i']

# %%
#find symmetric difference between two sets
s1={1,2,3}
s2={3,4,5}
s=s1^s2
print(s)
# Out:
# {1, 2, 4, 5}

# %%
#create a dictionary and print all keys and values
dic={1:'h',2:'a',3:'r',4:'s'}
print(dic.values())
# Out:
# dict_values(['h', 'a', 'r', 's'])

# %%
#add a new key_value pair
dic={1:'h',2:'a',3:'r',4:'s'}
dic.update({5:'i'})
print(dic)
# Out:
# {1: 'h', 2: 'a', 3: 'r', 4: 's', 5: 'i'}

# %%
#update value of an existing key
dic={1:'h',2:'a',3:'r',4:'s'}
dic[1]='H'
print(dic)
# Out:
# {1: 'H', 2: 'a', 3: 'r', 4: 's'}

# %%
#delete a key from a dictionary
dic={1:'h',2:'a',3:'r',4:'s'}
dic.pop(4)
print(dic)
# Out:
# {1: 'h', 2: 'a', 3: 'r'}

# %%
#loop through dictionary items
dic={1:'h',2:'a',3:'r',4:'s'}
for key,value in dic.items():
    print(f"{key}:{value}")
# Out:
# 1:h
# 2:a
# 3:r
# 4:s

# %%
#merge two dictionaries
d1={1:'h',2:'a'}
d2={3:'r',3:'s'}
d1.update(d2)
print(d1)
# Out:
# {1: 'h', 2: 'a', 3: 's'}

# %%
#find maximum value in dictionary
dic={"a":23,"b":56,"c":40}
print(max(dic.values()))
# Out:
# 56

# %%
#count frequency of elements using dictionary
l=[2,3,4,5,6,3,4,5,6]
d={}
for i in l:
    if i in d:
        d[i]+=1
    else:
        d[i]=1
print(d)
# Out:
# {2: 1, 3: 2, 4: 2, 5: 2, 6: 2}

# %%
#MINI PROJECT- HANGMAN GAME

import random

words = ["apple", "tiger", "chair", "robot", "plant"]

word = random.choice(words)
word_letters = set(word)
guessed_letters = set()

attempts = 6

stages = [
    """ 
-----
|   |
|
|
|
|
=========
""",
    """ 
-----
|   |
O   |
|
|
|
=========
""",
    """ 
-----
|   |
O   |
|   |
|
|
=========
""",
    """ 
-----
|   |
O   |
/|  |
|
|
=========
""",
    """ 
-----
|   |
O   |
/|\ |
|
|
=========
""",
    """ 
-----
|   |
O   |
/|\ |
/   |
|
=========
""",
    """ 
-----
|   |
O   |
/|\ |
/ \ |
|
=========
"""
]

print("HANGMAN")

while attempts > 0 and word_letters:
    print(stages[6 - attempts])

    display_word = [letter if letter in guessed_letters else "_" for letter in word]
    print("Word:", " ".join(display_word))

    guess = input("Enter a letter: ").lower()

    if not guess.isalpha() or len(guess) != 1:
        print(" Please enter a single valid letter.\n")

    if guess in guessed_letters:
        print("You already guessed that letter.\n")

    guessed_letters.add(guess)

    if guess in word_letters:
        word_letters.remove(guess)
        print("Correct!\n")
    else:
        attempts -= 1
        print(f" Wrong guess! Attempts left: {attempts}\n")

print(stages[6 - attempts])

if not word_letters:
    print(f"Congratulations! You guessed the word: {word}")
else:
    print(f" Game Over! The word was: {word}")
# Out:
# HANGMAN
#
# -----
# |   |
# |
# |
# |
# |
# ...
#
# Word: _ _ _ _ _
# Enter a letter:  a
# Correct!
#
#
# -----
# |   |
# |
# |
# |
# |
# ...
#
# Word: _ _ a _ _
# Enter a letter:  h
#  Wrong guess! Attempts left: 5
#
#
# -----
# |   |
# O   |
# |
# |
# |
# ...
#
# Word: _ _ a _ _
# Enter a letter:  k
#  Wrong guess! Attempts left: 4
#
#
# -----
# |   |
# O   |
# |   |
# |
# |
# ...
#
# Word: _ _ a _ _
# Enter a letter:
#  Please enter a single valid letter.
#
#  Wrong guess! Attempts left: 3
#
#
# -----
# |   |
# O   |
# /|  |
# |
# |
# ...
#
# Word: _ _ a _ _
# Enter a letter:  l
# Correct!
#
#
# -----
# |   |
# O   |
# /|  |
# |
# |
# ...
#
# Word: _ l a _ _
# Enter a letter:  a
# You already guessed that letter.
#
#  Wrong guess! Attempts left: 2
#
#
# -----
# |   |
# O   |
# /|\ |
# |
# |
# ...
#
# Word: _ l a _ _
# Enter a letter:  p
# Correct!
#
#
# -----
# |   |
# O   |
# /|\ |
# |
# |
# ...
#
# Word: p l a _ _
# Enter a letter:  n
# Correct!
#
#
# -----
# |   |
# O   |
# /|\ |
# |
# |
# ...
#
# Word: p l a n _
# ...
